# %%
# !pip install hopsworks
# Out:
# Requirement already satisfied: hopsworks in /usr/local/lib/python3.10/dist-packages (4.1.4)
# Requirement already satisfied: pyhumps==1.6.1 in /usr/local/lib/python3.10/dist-packages (from hopsworks) (1.6.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from hopsworks) (2.32.3)
# Requirement already satisfied: furl in /usr/local/lib/python3.10/dist-packages (from hopsworks) (2.1.3)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.10/dist-packages (from hopsworks) (1.35.92)
# Requirement already satisfied: pandas<2.2.0 in /usr/local/lib/python3.10/dist-packages (from hopsworks) (2.1.4)
# Requirement already satisfied: pyjks in /usr/local/lib/python3.10/dist-packages (from hopsworks) (20.0.0)
# Requirement already satisfied: mock in /usr/local/lib/python3.10/dist-packages (from hopsworks) (5.1.0)
# Requirement already satisfied: avro==1.11.3 in /usr/local/lib/python3.10/dist-packages (from hopsworks) (1.11.3)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.10/dist-packages (from hopsworks) (2.0.29)
# Requirement already satisfied: PyMySQL[rsa] in /usr/local/lib/python3.10/dist-packages (from hopsworks) (1.1.1)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.10/dist-packages (from hopsworks) (5.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from hopsworks) (2024.10.0)
# Requirement already satisfied: retrying in /usr/local/lib/python3.10/dist-packages (from hopsworks) (1.3.4)
# Requirement already satisfied: hopsworks_aiomysql==0.2.1 in /usr/local/lib/python3.10/dist-packages (from hopsworks_aiomysql[sa]==0.2.1->hopsworks) (0.2.1)
# Requirement already satisfied: opensearch-py<=2.4.2,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from hopsworks) (2.4.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from hopsworks) (4.67.1)
# Requirement already satisfied: grpcio<2.0.0,>=1.49.1 in /usr/local/lib/python3.10/dist-packages (from hopsworks) (1.68.1)
# Requirement already satisfied: protobuf<5.0.0,>=4.25.4 in /usr/local/lib/python3.10/dist-packages (from hopsworks) (4.25.5)
# Requirement already satisfied: urllib3>=1.26.18 in /usr/local/lib/python3.10/dist-packages (from opensearch-py<=2.4.2,>=1.1.0->hopsworks) (2.2.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from opensearch-py<=2.4.2,>=1.1.0->hopsworks) (1.17.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from opensearch-py<=2.4.2,>=1.1.0->hopsworks) (2.8.2)
# Requirement already satisfied: certifi>=2022.12.07 in /usr/local/lib/python3.10/dist-packages (from opensearch-py<=2.4.2,>=1.1.0->hopsworks) (2024.12.14)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas<2.2.0->hopsworks) (1.26.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.2.0->hopsworks) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.2.0->hopsworks) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->hopsworks) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->hopsworks) (3.10)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy->hopsworks) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy->hopsworks) (3.1.1)
# Requirement already satisfied: botocore<1.36.0,>=1.35.92 in /usr/local/lib/python3.10/dist-packages (from boto3->hopsworks) (1.35.92)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from boto3->hopsworks) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from boto3->hopsworks) (0.10.4)
# Requirement already satisfied: orderedmultidict>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from furl->hopsworks) (1.0.1)
# Requirement already satisfied: javaobj-py3 in /usr/local/lib/python3.10/dist-packages (from pyjks->hopsworks) (0.4.4)
# Requirement already satisfied: pyasn1>=0.3.5 in /usr/local/lib/python3.10/dist-packages (from pyjks->hopsworks) (0.6.1)
# Requirement already satisfied: pyasn1-modules in /usr/local/lib/python3.10/dist-packages (from pyjks->hopsworks) (0.4.1)
# Requirement already satisfied: pycryptodomex in /usr/local/lib/python3.10/dist-packages (from pyjks->hopsworks) (3.21.0)
# Requirement already satisfied: twofish in /usr/local/lib/python3.10/dist-packages (from pyjks->hopsworks) (0.3.0)
# Requirement already satisfied: cryptography in /usr/local/lib/python3.10/dist-packages (from PyMySQL[rsa]->hopsworks) (43.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography->PyMySQL[rsa]->hopsworks) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography->PyMySQL[rsa]->hopsworks) (2.22)

# %%
import datetime
import requests
import pandas as pd
import hopsworks
import datetime
from pathlib import Path
import json
import re
import os
import warnings
warnings.filterwarnings("ignore")

# %%
with open('hopsworks-api-key.txt', 'r') as file:
    os.environ["HOPSWORKS_API_KEY"] = file.read().rstrip()

project = hopsworks.login()
# Out:
# Connection closed.
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/1171606

# %%
df = pd.read_csv('Airline_Delay_Cause.csv', skipinitialspace=True)
df
# Out:
#       year  month carrier               carrier_name airport  \
# 0     2024      9      9E          Endeavor Air Inc.     ATL
# 1     2024      9      AA  American Airlines Network     ATL
# 2     2024      9      AS    Alaska Airlines Network     ATL
# 3     2024      9      B6            JetBlue Airways     ATL
# 4     2024      9      DL    Delta Air Lines Network     ATL
# ...    ...    ...     ...                        ...     ...
# 1600  2014      7      MQ                  Envoy Air     ATL
# 1601  2014      7      OO      SkyWest Airlines Inc.     ATL
# 1602  2014      7      UA      United Air Lines Inc.     ATL
# 1603  2014      7      US            US Airways Inc.     ATL
# 1604  2014      7      WN     Southwest Airlines Co.     ATL
#
#                                            airport_name  arr_flights  \
# 0     Atlanta, GA: Hartsfield-Jackson Atlanta Intern...       2204.0
# 1     Atlanta, GA: Hartsfield-Jackson Atlanta Intern...        709.0
# 2     Atlanta, GA: Hartsfield-Jackson Atlanta Intern...        138.0
# 3     Atlanta, GA: Hartsfield-Jackson Atlanta Intern...        276.0
# 4     Atlanta, GA: Hartsfield-Jackson Atlanta Intern...      19151.0
# ...                                                 ...          ...
# 1600  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...         81.0
# 1601  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...        198.0
# 1602  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...         61.0
# 1603  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...        474.0
# 1604  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...       1685.0
#
#       arr_del15  carrier_ct  weather_ct  ...  security_ct  late_aircraft_ct  \
# 0         280.0       61.70       17.36  ...         0.00            112.57
# 1         159.0       63.21        3.02  ...         0.07             57.46
# 2          37.0       10.67        1.63  ...         0.00              6.23
# 3          57.0       26.27        0.98  ...         0.00             10.91
# 4        2429.0      709.98      122.72  ...         0.68            904.72
# ...         ...         ...         ...  ...          ...               ...
# 1600       21.0        3.28        0.20  ...         0.00              6.13
# 1601       48.0       16.68        1.67  ...         0.00             11.13
# 1602       37.0       15.79        0.28  ...         0.00              9.41
# 1603      111.0       55.69        7.03  ...         1.20             18.17
# 1604      427.0      122.80       17.21  ...         0.00            208.62
#
#       arr_cancelled  arr_diverted  arr_delay  carrier_delay  weather_delay  \
# 0              40.0           4.0    24383.0         7840.0         2297.0
# 1               4.0           0.0    11435.0         5343.0          238.0
# 2               2.0           1.0     1859.0          606.0          135.0
# 3               0.0           1.0     3588.0         1981.0           40.0
# 4             101.0          30.0   163868.0        68972.0        12036.0
# ...             ...           ...        ...            ...            ...
# 1600            5.0           1.0      843.0           78.0            8.0
# 1601            4.0           3.0     2173.0          821.0          230.0
# 1602            0.0           1.0     1665.0          652.0           13.0
# 1603            3.0           0.0     5871.0         3043.0          757.0
# 1604           20.0           5.0    24733.0         6642.0         1449.0
#
#       nas_delay  security_delay  late_aircraft_delay
# 0        3690.0             0.0              10556.0
# 1        1327.0             6.0               4521.0
# 2         907.0             0.0                211.0
# 3         657.0             0.0                910.0
# 4       26112.0            32.0              56716.0
# ...         ...             ...                  ...
# 1600      535.0             0.0                222.0
# 1601      604.0             0.0                518.0
# 1602      386.0             0.0                614.0
# 1603     1193.0            32.0                846.0
# 1604     2888.0             0.0              13754.0
#
# [1605 rows x 21 columns]

# %%
import pandas as pd



# Combine 'year' and 'month' columns into a 'year_month' column in 'YYYY-MM' format
df['year'] = df['year'].astype(int)
df['month'] = df['month'].astype(int)

df
# Out:
#       year  month carrier               carrier_name airport  \
# 0     2024      9      9E          Endeavor Air Inc.     ATL
# 1     2024      9      AA  American Airlines Network     ATL
# 2     2024      9      AS    Alaska Airlines Network     ATL
# 3     2024      9      B6            JetBlue Airways     ATL
# 4     2024      9      DL    Delta Air Lines Network     ATL
# ...    ...    ...     ...                        ...     ...
# 1600  2014      7      MQ                  Envoy Air     ATL
# 1601  2014      7      OO      SkyWest Airlines Inc.     ATL
# 1602  2014      7      UA      United Air Lines Inc.     ATL
# 1603  2014      7      US            US Airways Inc.     ATL
# 1604  2014      7      WN     Southwest Airlines Co.     ATL
#
#                                            airport_name  arr_flights  \
# 0     Atlanta, GA: Hartsfield-Jackson Atlanta Intern...       2204.0
# 1     Atlanta, GA: Hartsfield-Jackson Atlanta Intern...        709.0
# 2     Atlanta, GA: Hartsfield-Jackson Atlanta Intern...        138.0
# 3     Atlanta, GA: Hartsfield-Jackson Atlanta Intern...        276.0
# 4     Atlanta, GA: Hartsfield-Jackson Atlanta Intern...      19151.0
# ...                                                 ...          ...
# 1600  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...         81.0
# 1601  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...        198.0
# 1602  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...         61.0
# 1603  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...        474.0
# 1604  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...       1685.0
#
#       arr_del15  carrier_ct  weather_ct  ...  security_ct  late_aircraft_ct  \
# 0         280.0       61.70       17.36  ...         0.00            112.57
# 1         159.0       63.21        3.02  ...         0.07             57.46
# 2          37.0       10.67        1.63  ...         0.00              6.23
# 3          57.0       26.27        0.98  ...         0.00             10.91
# 4        2429.0      709.98      122.72  ...         0.68            904.72
# ...         ...         ...         ...  ...          ...               ...
# 1600       21.0        3.28        0.20  ...         0.00              6.13
# 1601       48.0       16.68        1.67  ...         0.00             11.13
# 1602       37.0       15.79        0.28  ...         0.00              9.41
# 1603      111.0       55.69        7.03  ...         1.20             18.17
# 1604      427.0      122.80       17.21  ...         0.00            208.62
#
#       arr_cancelled  arr_diverted  arr_delay  carrier_delay  weather_delay  \
# 0              40.0           4.0    24383.0         7840.0         2297.0
# 1               4.0           0.0    11435.0         5343.0          238.0
# 2               2.0           1.0     1859.0          606.0          135.0
# 3               0.0           1.0     3588.0         1981.0           40.0
# 4             101.0          30.0   163868.0        68972.0        12036.0
# ...             ...           ...        ...            ...            ...
# 1600            5.0           1.0      843.0           78.0            8.0
# 1601            4.0           3.0     2173.0          821.0          230.0
# 1602            0.0           1.0     1665.0          652.0           13.0
# 1603            3.0           0.0     5871.0         3043.0          757.0
# 1604           20.0           5.0    24733.0         6642.0         1449.0
#
#       nas_delay  security_delay  late_aircraft_delay
# 0        3690.0             0.0              10556.0
# 1        1327.0             6.0               4521.0
# 2         907.0             0.0                211.0
# 3         657.0             0.0                910.0
# 4       26112.0            32.0              56716.0
# ...         ...             ...                  ...
# 1600      535.0             0.0                222.0
# 1601      604.0             0.0                518.0
# 1602      386.0             0.0                614.0
# 1603     1193.0            32.0                846.0
# 1604     2888.0             0.0              13754.0
#
# [1605 rows x 21 columns]

# %%
df = df.drop(columns=['airport','airport_name'])
df
# Out:
#       year  month carrier               carrier_name  arr_flights  arr_del15  \
# 0     2024      9      9E          Endeavor Air Inc.       2204.0      280.0
# 1     2024      9      AA  American Airlines Network        709.0      159.0
# 2     2024      9      AS    Alaska Airlines Network        138.0       37.0
# 3     2024      9      B6            JetBlue Airways        276.0       57.0
# 4     2024      9      DL    Delta Air Lines Network      19151.0     2429.0
# ...    ...    ...     ...                        ...          ...        ...
# 1600  2014      7      MQ                  Envoy Air         81.0       21.0
# 1601  2014      7      OO      SkyWest Airlines Inc.        198.0       48.0
# 1602  2014      7      UA      United Air Lines Inc.         61.0       37.0
# 1603  2014      7      US            US Airways Inc.        474.0      111.0
# 1604  2014      7      WN     Southwest Airlines Co.       1685.0      427.0
#
#       carrier_ct  weather_ct  nas_ct  security_ct  late_aircraft_ct  \
# 0          61.70       17.36   88.36         0.00            112.57
# 1          63.21        3.02   35.25         0.07             57.46
# 2          10.67        1.63   18.47         0.00              6.23
# 3          26.27        0.98   18.84         0.00             10.91
# 4         709.98      122.72  690.90         0.68            904.72
# ...          ...         ...     ...          ...               ...
# 1600        3.28        0.20   11.39         0.00              6.13
# 1601       16.68        1.67   18.52         0.00             11.13
# 1602       15.79        0.28   11.51         0.00              9.41
# 1603       55.69        7.03   28.91         1.20             18.17
# 1604      122.80       17.21   78.38         0.00            208.62
#
#       arr_cancelled  arr_diverted  arr_delay  carrier_delay  weather_delay  \
# 0              40.0           4.0    24383.0         7840.0         2297.0
# 1               4.0           0.0    11435.0         5343.0          238.0
# 2               2.0           1.0     1859.0          606.0          135.0
# 3               0.0           1.0     3588.0         1981.0           40.0
# 4             101.0          30.0   163868.0        68972.0        12036.0
# ...             ...           ...        ...            ...            ...
# 1600            5.0           1.0      843.0           78.0            8.0
# 1601            4.0           3.0     2173.0          821.0          230.0
# 1602            0.0           1.0     1665.0          652.0           13.0
# 1603            3.0           0.0     5871.0         3043.0          757.0
# 1604           20.0           5.0    24733.0         6642.0         1449.0
#
#       nas_delay  security_delay  late_aircraft_delay
# 0        3690.0             0.0              10556.0
# 1        1327.0             6.0               4521.0
# 2         907.0             0.0                211.0
# 3         657.0             0.0                910.0
# 4       26112.0            32.0              56716.0
# ...         ...             ...                  ...
# 1600      535.0             0.0                222.0
# 1601      604.0             0.0                518.0
# 1602      386.0             0.0                614.0
# 1603     1193.0            32.0                846.0
# 1604     2888.0             0.0              13754.0
#
# [1605 rows x 19 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1605 entries, 0 to 1604
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   year                 1605 non-null   int64
#  1   month                1605 non-null   int64
#  2   carrier              1605 non-null   object
#  3   carrier_name         1605 non-null   object
#  4   arr_flights          1605 non-null   float64
#  5   arr_del15            1604 non-null   float64
#  6   carrier_ct           1605 non-null   float64
#  7   weather_ct           1605 non-null   float64
#  8   nas_ct               1605 non-null   float64
#  9   security_ct          1605 non-null   float64
#  10  late_aircraft_ct     1605 non-null   float64
#  11  arr_cancelled        1605 non-null   float64
#  12  arr_diverted         1605 non-null   float64
#  13  arr_delay            1605 non-null   float64
#  14  carrier_delay        1605 non-null   float64
#  15  weather_delay        1605 non-null   float64
#  16  nas_delay            1605 non-null   float64
#  17  security_delay       1605 non-null   float64
#  18  late_aircraft_delay  1605 non-null   float64
# dtypes: float64(15), int64(2), object(2)
# memory usage: 238.4+ KB

# %%
df.dropna(inplace=True)
df
# Out:
#       year  month carrier               carrier_name  arr_flights  arr_del15  \
# 0     2024      9      9E          Endeavor Air Inc.       2204.0      280.0
# 1     2024      9      AA  American Airlines Network        709.0      159.0
# 2     2024      9      AS    Alaska Airlines Network        138.0       37.0
# 3     2024      9      B6            JetBlue Airways        276.0       57.0
# 4     2024      9      DL    Delta Air Lines Network      19151.0     2429.0
# ...    ...    ...     ...                        ...          ...        ...
# 1600  2014      7      MQ                  Envoy Air         81.0       21.0
# 1601  2014      7      OO      SkyWest Airlines Inc.        198.0       48.0
# 1602  2014      7      UA      United Air Lines Inc.         61.0       37.0
# 1603  2014      7      US            US Airways Inc.        474.0      111.0
# 1604  2014      7      WN     Southwest Airlines Co.       1685.0      427.0
#
#       carrier_ct  weather_ct  nas_ct  security_ct  late_aircraft_ct  \
# 0          61.70       17.36   88.36         0.00            112.57
# 1          63.21        3.02   35.25         0.07             57.46
# 2          10.67        1.63   18.47         0.00              6.23
# 3          26.27        0.98   18.84         0.00             10.91
# 4         709.98      122.72  690.90         0.68            904.72
# ...          ...         ...     ...          ...               ...
# 1600        3.28        0.20   11.39         0.00              6.13
# 1601       16.68        1.67   18.52         0.00             11.13
# 1602       15.79        0.28   11.51         0.00              9.41
# 1603       55.69        7.03   28.91         1.20             18.17
# 1604      122.80       17.21   78.38         0.00            208.62
#
#       arr_cancelled  arr_diverted  arr_delay  carrier_delay  weather_delay  \
# 0              40.0           4.0    24383.0         7840.0         2297.0
# 1               4.0           0.0    11435.0         5343.0          238.0
# 2               2.0           1.0     1859.0          606.0          135.0
# 3               0.0           1.0     3588.0         1981.0           40.0
# 4             101.0          30.0   163868.0        68972.0        12036.0
# ...             ...           ...        ...            ...            ...
# 1600            5.0           1.0      843.0           78.0            8.0
# 1601            4.0           3.0     2173.0          821.0          230.0
# 1602            0.0           1.0     1665.0          652.0           13.0
# 1603            3.0           0.0     5871.0         3043.0          757.0
# 1604           20.0           5.0    24733.0         6642.0         1449.0
#
#       nas_delay  security_delay  late_aircraft_delay
# 0        3690.0             0.0              10556.0
# 1        1327.0             6.0               4521.0
# 2         907.0             0.0                211.0
# 3         657.0             0.0                910.0
# 4       26112.0            32.0              56716.0
# ...         ...             ...                  ...
# 1600      535.0             0.0                222.0
# 1601      604.0             0.0                518.0
# 1602      386.0             0.0                614.0
# 1603     1193.0            32.0                846.0
# 1604     2888.0             0.0              13754.0
#
# [1604 rows x 19 columns]

# %% [markdown]
# ---

# %%
import pandas as pd

# Load CSV data
df_wea = pd.read_csv('weather-data.csv')
df_wea
# Out:
#                    time  temperature_2m (°C)  snowfall (cm)  snow_depth (m)  \
# 0      2014-01-01T00:00                  4.5            0.0             0.0
# 1      2014-01-01T01:00                  3.7            0.0             0.0
# 2      2014-01-01T02:00                  3.2            0.0             0.0
# 3      2014-01-01T03:00                  2.7            0.0             0.0
# 4      2014-01-01T04:00                  2.0            0.0             0.0
# ...                 ...                  ...            ...             ...
# 96427  2024-12-31T19:00                 18.7            0.0             NaN
# 96428  2024-12-31T20:00                 18.7            0.0             NaN
# 96429  2024-12-31T21:00                 17.7            0.0             NaN
# 96430  2024-12-31T22:00                 15.9            0.0             NaN
# 96431  2024-12-31T23:00                 13.4            0.0             NaN
#
#        weather_code (wmo code)  cloud_cover (%)  wind_speed_10m (km/h)  \
# 0                            3              100                    6.1
# 1                            3              100                    6.1
# 2                            3              100                    6.0
# 3                            3              100                    5.5
# 4                            3              100                    6.1
# ...                        ...              ...                    ...
# 96427                        0               17                   23.3
# 96428                        0                2                   26.6
# 96429                        0                0                   25.3
# 96430                        0                0                   22.2
# 96431                        0                5                   20.7
#
#        wind_direction_10m (°)
# 0                         298
# 1                         310
# 2                         327
# 3                         328
# 4                         332
# ...                       ...
# 96427                     243
# 96428                     257
# 96429                     265
# 96430                     275
# 96431                     295
#
# [96432 rows x 8 columns]

# %%
import pandas as pd


# Load CSV data
df_wea = pd.read_csv('weather-data.csv')
df_wea['time'] = pd.to_datetime(df_wea['time'])  # or df_wea['timestamp']
# Extract date and time components from the timestamp
df_wea['date'] = df_wea['time'].dt.date
df_wea['hour'] = df_wea['time'].dt.hour
df_wea.rename(columns={'month': 'date'}, inplace=True)

# Group by date and calculate daily statistic
# Extract the month and year from the 'time' column to group by
df_wea['year'] = df_wea['time'].dt.year
df_wea['month'] = df_wea['time'].dt.month

df_wea.rename(columns={'temperature_2m (°C)': 'temperature_2m'}, inplace=True)
df_wea.rename(columns={'snowfall (cm)': 'snowfall'}, inplace=True)
df_wea.rename(columns={'snow_depth (m)': 'snow_depth'}, inplace=True)
df_wea.rename(columns={'cloud_cover (%)': 'cloud_cover'}, inplace=True)
df_wea.rename(columns={'wind_speed_10m (km/h)': 'wind_speed_10m'}, inplace=True)
df_wea.rename(columns={'wind_direction_10m (°)': 'wind_direction_10m'}, inplace=True)



df_wea = df_wea.groupby(['year', 'month']).agg({
    'temperature_2m': 'mean',
    'snowfall': 'sum',
    'snow_depth': 'mean',
    'cloud_cover': 'mean',
    'wind_speed_10m': 'mean',
    'wind_direction_10m': 'mean'
}).reset_index()

df_wea
# Out:
#      year  month  temperature_2m  snowfall  snow_depth  cloud_cover  \
# 0    2014      1        1.921505      4.41    0.004126    43.788978
# 1    2014      2        7.051786     11.55    0.006235    65.367560
# 2    2014      3        9.742876      0.00    0.000000    60.543011
# 3    2014      4       15.451111      0.00    0.000000    58.587500
# 4    2014      5       20.724597      0.00    0.000000    53.099462
# ..    ...    ...             ...       ...         ...          ...
# 127  2024      8       25.959005      0.00    0.000000    25.107527
# 128  2024      9       23.060000      0.00    0.000000    51.530556
# 129  2024     10       17.751344      0.00    0.000000    14.504032
# 130  2024     11       14.107083      0.00    0.000000    51.059722
# 131  2024     12        7.502823      0.00    0.000000    46.978495
#
#      wind_speed_10m  wind_direction_10m
# 0         13.489919          232.897849
# 1         12.793601          236.766369
# 2         12.783199          208.944892
# 3         13.065000          196.804167
# 4          9.122043          206.063172
# ..              ...                 ...
# 127       10.002151          197.163978
# 128       13.089583          152.679167
# 129       10.080108          166.244624
# 130       11.963194          192.959722
# 131       11.704301          207.711022
#
# [132 rows x 8 columns]

# %%
df_wea.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   year                132 non-null    int32
#  1   month               132 non-null    int32
#  2   temperature_2m      132 non-null    float64
#  3   snowfall            132 non-null    float64
#  4   snow_depth          132 non-null    float64
#  5   cloud_cover         132 non-null    float64
#  6   wind_speed_10m      132 non-null    float64
#  7   wind_direction_10m  132 non-null    float64
# dtypes: float64(6), int32(2)
# memory usage: 7.3 KB

# %% [markdown]
# ---

# %%
fs = project.get_feature_store()

# %%
merged_data = pd.merge(
    df,
    df_wea,
    left_on=['year', 'month'],
    right_on=['year', 'month'],
    how='left'  # 'left' keeps all flight data even if weather is missing
)

# %%
merged_data
# Out:
#       year  month carrier               carrier_name  arr_flights  arr_del15  \
# 0     2024      9      9E          Endeavor Air Inc.       2204.0      280.0
# 1     2024      9      AA  American Airlines Network        709.0      159.0
# 2     2024      9      AS    Alaska Airlines Network        138.0       37.0
# 3     2024      9      B6            JetBlue Airways        276.0       57.0
# 4     2024      9      DL    Delta Air Lines Network      19151.0     2429.0
# ...    ...    ...     ...                        ...          ...        ...
# 1599  2014      7      MQ                  Envoy Air         81.0       21.0
# 1600  2014      7      OO      SkyWest Airlines Inc.        198.0       48.0
# 1601  2014      7      UA      United Air Lines Inc.         61.0       37.0
# 1602  2014      7      US            US Airways Inc.        474.0      111.0
# 1603  2014      7      WN     Southwest Airlines Co.       1685.0      427.0
#
#       carrier_ct  weather_ct  nas_ct  security_ct  ...  weather_delay  \
# 0          61.70       17.36   88.36         0.00  ...         2297.0
# 1          63.21        3.02   35.25         0.07  ...          238.0
# 2          10.67        1.63   18.47         0.00  ...          135.0
# 3          26.27        0.98   18.84         0.00  ...           40.0
# 4         709.98      122.72  690.90         0.68  ...        12036.0
# ...          ...         ...     ...          ...  ...            ...
# 1599        3.28        0.20   11.39         0.00  ...            8.0
# 1600       16.68        1.67   18.52         0.00  ...          230.0
# 1601       15.79        0.28   11.51         0.00  ...           13.0
# 1602       55.69        7.03   28.91         1.20  ...          757.0
# 1603      122.80       17.21   78.38         0.00  ...         1449.0
#
#       nas_delay  security_delay  late_aircraft_delay  temperature_2m  \
# 0        3690.0             0.0              10556.0       23.060000
# 1        1327.0             6.0               4521.0       23.060000
# 2         907.0             0.0                211.0       23.060000
# 3         657.0             0.0                910.0       23.060000
# 4       26112.0            32.0              56716.0       23.060000
# ...         ...             ...                  ...             ...
# 1599      535.0             0.0                222.0       24.931586
# 1600      604.0             0.0                518.0       24.931586
# 1601      386.0             0.0                614.0       24.931586
# 1602     1193.0            32.0                846.0       24.931586
# 1603     2888.0             0.0              13754.0       24.931586
#
#       snowfall  snow_depth  cloud_cover  wind_speed_10m  wind_direction_10m
# 0          0.0         0.0    51.530556       13.089583          152.679167
# 1          0.0         0.0    51.530556       13.089583          152.679167
# 2          0.0         0.0    51.530556       13.089583          152.679167
# 3          0.0         0.0    51.530556       13.089583          152.679167
# 4          0.0         0.0    51.530556       13.089583          152.679167
# ...        ...         ...          ...             ...                 ...
# 1599       0.0         0.0    59.395161        8.178763          204.651882
# 1600       0.0         0.0    59.395161        8.178763          204.651882
# 1601       0.0         0.0    59.395161        8.178763          204.651882
# 1602       0.0         0.0    59.395161        8.178763          204.651882
# 1603       0.0         0.0    59.395161        8.178763          204.651882
#
# [1604 rows x 25 columns]

# %%
import numpy as np

#Create 'event_time' in DATE format for feature group
merged_data['event_time'] = pd.to_datetime(
    merged_data['year'].astype(str) + '-' + merged_data['month'].astype(str) + '-01'
).dt.date

#Cyclical encoding for month to capture cyclical patterns
merged_data['month_sin'] = np.sin(2 * np.pi * merged_data['month'] / 12)
merged_data['month_cos'] = np.cos(2 * np.pi * merged_data['month'] / 12)

#Create feature group
delay_data = fs.get_or_create_feature_group(
    name='airline_delay2',
    description='Flight delay data merged with weather conditions',
    version=1,
    primary_key=['year', 'month', 'carrier'],  # Ensure primary key uniqueness
    event_time="event_time"
)

# %%
delay_data.insert(merged_data, write_options={"wait_for_job": True})
# Out:
# Feature Group created successfully, explore it at
# https://c.app.hopsworks.ai:443/p/1171606/fs/1162309/fg/1393628
# Uploading Dataframe: 100.00% |██████████| Rows 1604/1604 | Elapsed Time: 00:02 | Remaining Time: 00:00
# Launching job: airline_delay2_1_offline_fg_materialization
# Job started successfully, you can follow the progress at
# https://c.app.hopsworks.ai:443/p/1171606/jobs/named/airline_delay2_1_offline_fg_materialization/executions
# (Job('airline_delay2_1_offline_fg_materialization', 'SPARK'), None)
